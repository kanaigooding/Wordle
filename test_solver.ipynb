# %%
from wordle_solver import WordleSolver
import json

# %%
def feedback(word, guess):
    """Generates feedback for a guess based on the actual word."""
    return ['G' if c == g else 'Y' if g in word else 'B' for c, g in zip(word, guess)]

# %%
def test_solver(solver, word):
    """Tests the solver for a given word, returns the number of guesses."""
    guesses = []
    while len(solver.possible_words) > 1:
        guess = solver.get_optimal_guess()
        guesses.append(guess)
        solver.adjust_guess(guess, feedback(word, guess))
    return guesses

# %%
solver = WordleSolver('frequencyMaps/validwords.txt', 'frequencyMaps/word_freq_map.json',
                      'frequencyMaps/letter_freq_map.json')
words = solver.words

# %%
results = {}
for word in words:
    solver.reset()  # reset solver's possible words
    guesses = test_solver(solver, word)
    results[word] = len(guesses)
    print(f"Correct answer: {word}")
    print("Guesses made: ", ", ".join(guesses))
    print(f"Number of guesses: {len(guesses)}")
    print("------------------------")
# Out:
# Correct answer: aahed
# Guesses made:  which, other, ashes
# Number of guesses: 3
# ------------------------
# Correct answer: aalii
# Guesses made:  which, first, again, avoid, alkie, aumil
# Number of guesses: 6
# ------------------------
# Correct answer: aargh
# Guesses made:  which, death, laugh, sangh
# Number of guesses: 4
# ------------------------
# Correct answer: aarti
# Guesses made:  which, first, parti
# Number of guesses: 3
# ------------------------
# Correct answer: abaca
# Guesses made:  which, place, track, abaca
# Number of guesses: 4
# ------------------------
# Correct answer: abaci
# Guesses made:  which, since, cocci, abaci
# Number of guesses: 4
# ------------------------
# Correct answer: aback
# Guesses made:  which, place, track, snack, aback
# Number of guesses: 5
# ------------------------
# Correct answer: abacs
# Guesses made:  which, place, track, abaca
# Number of guesses: 4
# ------------------------
# Correct answer: abaft
# Guesses made:  which, about, abaft
# Number of guesses: 3
# ------------------------
# Correct answer: abaka
# Guesses made:  which, about, abbey, abram, aband, abaka
# Number of guesses: 6
# ------------------------
# Correct answer: abamp
# Guesses made:  which, about, abbey, abram
# Number of guesses: 4
# ------------------------
# Correct answer: aband
# Guesses made:  which, about, abbey, abram, aband
# Number of guesses: 5
# ------------------------
# Correct answer: abase
# Guesses made:  which, about, abbey, abase
# Number of guesses: 4
# ------------------------
# Correct answer: abash
# Guesses made:  which, death, graph, flash, smash, quash
# Number of guesses: 6
# ------------------------
# Correct answer: abask
# Guesses made:  which, about, abbey, abram, aband, abaka
# Number of guesses: 6
# ------------------------
# Correct answer: abate
# Guesses made:  which, about, abate
# Number of guesses: 3
# ------------------------
# Correct answer: abaya
# Guesses made:  which, about, abbey, abyss
# Number of guesses: 4
# ------------------------
# Correct answer: abbas
# Guesses made:  which, about, abbey
# Number of guesses: 3
# ------------------------
# Correct answer: abbed
# Guesses made:  which, about, abbey, abbes
# Number of guesses: 4
# ------------------------
# Correct answer: abbes
# Guesses made:  which, about, abbey, abbes
# Number of guesses: 4
# ------------------------
# Correct answer: abbey
# Guesses made:  which, about, abbey
# Number of guesses: 3
# ------------------------
# Correct answer: abbot
# Guesses made:  which, about
# Number of guesses: 2
# ------------------------
# Correct answer: abcee
# Guesses made:  which, could, scene, emcee
# Number of guesses: 4
# ------------------------
# Correct answer: abeam
# Guesses made:  which, about, abbey, abase, abeam
# Number of guesses: 5
# ------------------------
# Correct answer: abear
# Guesses made:  which, about, abbey, abase, abeam
# Number of guesses: 5
# ------------------------
# Correct answer: abele
# Guesses made:  which, about, abbey, abase
# Number of guesses: 4
# ------------------------
# Correct answer: abers
# Guesses made:  which, about, abbey, abase
# Number of guesses: 4
# ------------------------
# Correct answer: abets
# Guesses made:  which, about, abate
# Number of guesses: 3
# ------------------------
# Correct answer: abhor
# Guesses made:  which, other, abhor
# Number of guesses: 3
# ------------------------
# Correct answer: abide
# Guesses made:  which, being, tribe
# Number of guesses: 3
# ------------------------
# Correct answer: abies
# Guesses made:  which, being, tribe, abies
# Number of guesses: 4
# ------------------------
# Correct answer: abled
# Guesses made:  which, about, abbey, abled
# Number of guesses: 4
# ------------------------
# Correct answer: abler
# Guesses made:  which, about, abbey, abled, abler
# Number of guesses: 5
# ------------------------
# Correct answer: ables
# Guesses made:  which, about, abbey, abled, abler
# Number of guesses: 5
# ------------------------
# Correct answer: ablet
# Guesses made:  which, about, abaft
# Number of guesses: 3
# ------------------------
# Correct answer: ablow
# Guesses made:  which, power, known, allow, aglow
# Number of guesses: 5
# ------------------------
# Correct answer: abmho
# Guesses made:  which, other, holds, abohm
# Number of guesses: 4
# ------------------------
# Correct answer: abode
# Guesses made:  which, about, above, abode
# Number of guesses: 4
# ------------------------
# Correct answer: abohm
# Guesses made:  which, other, holds, abohm
# Number of guesses: 4
# ------------------------
# Correct answer: aboil
# Guesses made:  which, first, again, avoid
# Number of guesses: 4
# ------------------------
# Correct answer: aboma
# Guesses made:  which, about, above, abord, aboon
# Number of guesses: 5
# ------------------------
# Correct answer: aboon
# Guesses made:  which, about, above, abord, aboon
# Number of guesses: 5
# ------------------------
# Correct answer: abord
# Guesses made:  which, about, above, abord
# Number of guesses: 4
# ------------------------
# Correct answer: abore
# Guesses made:  which, about, above, abode
# Number of guesses: 4
# ------------------------
# Correct answer: abort
# Guesses made:  which, about
# Number of guesses: 2
# ------------------------
# Correct answer: about
# Guesses made:  which, about
# Number of guesses: 2
# ------------------------
# Correct answer: above
# Guesses made:  which, about, above
# Number of guesses: 3
# ------------------------
# Correct answer: abram
# Guesses made:  which, about, abbey, abram
# Number of guesses: 4
# ------------------------
# Correct answer: abray
# Guesses made:  which, about, abbey
# Number of guesses: 3
# ------------------------
# Correct answer: abrim
# Guesses made:  which, first, maria
# Number of guesses: 3
# ------------------------
# Correct answer: abrin
# Guesses made:  which, first, maria, aerie, agrin
# Number of guesses: 5
# ------------------------
# Correct answer: abris
# Guesses made:  which, first, paris, auris, arris
# Number of guesses: 5
# ------------------------
# Correct answer: absey
# Guesses made:  which, about, abbey
# Number of guesses: 3
# ------------------------
# Correct answer: absit
# Guesses made:  which, first, split, absit
# Number of guesses: 4
# ------------------------
# Correct answer: abuna
# Guesses made:  which, about, abuse, abuzz
# Number of guesses: 4
# ------------------------
# Correct answer: abune
# Guesses made:  which, about, abuse
# Number of guesses: 3
# ------------------------
# Correct answer: abuse
# Guesses made:  which, about, abuse
# Number of guesses: 3
# ------------------------
# Correct answer: abuts
# Guesses made:  which, about
# Number of guesses: 2
# ------------------------
# Correct answer: abuzz
# Guesses made:  which, about, abuse, abuzz
# Number of guesses: 4
# ------------------------
# Correct answer: abyes
# Guesses made:  which, about, abbey
# Number of guesses: 3
# ------------------------
# Correct answer: abysm
# Guesses made:  which, about, abbey, abyss
# Number of guesses: 4
# ------------------------
# Correct answer: abyss
# Guesses made:  which, about, abbey, abyss
# Number of guesses: 4
# ------------------------
# Correct answer: acais
# Guesses made:  which, music, scrip
# Number of guesses: 3
# ------------------------
# Correct answer: acari
# Guesses made:  which, music, cited, acari
# Number of guesses: 4
# ------------------------
# Correct answer: accas
# Guesses made:  which, could, scene
# Number of guesses: 3
# ------------------------
# Correct answer: accoy
# Guesses made:  which, could, scope, actor
# Number of guesses: 4
# ------------------------
# Correct answer: acerb
# Guesses made:  which, could, scene, acerb
# Number of guesses: 4
# ------------------------
# Correct answer: acers
# Guesses made:  which, could, scene
# Number of guesses: 3
# ------------------------
# Correct answer: aceta
# Guesses made:  which, could, scene, acerb
# Number of guesses: 4
# ------------------------
# Correct answer: achar
# Guesses made:  which, cohen, achar
# Number of guesses: 3
# ------------------------
# Correct answer: ached
# Guesses made:  which, cohen, ached
# Number of guesses: 3
# ------------------------
# Correct answer: aches
# Guesses made:  which, cohen, ached
# Number of guesses: 3
# ------------------------
# Correct answer: achoo
# Guesses made:  which, cohen, achoo
# Number of guesses: 3
# ------------------------
# Correct answer: acids
# Guesses made:  which, crime, acids
# Number of guesses: 3
# ------------------------
# Correct answer: acidy
# Guesses made:  which, crime, acids
# Number of guesses: 3
# ------------------------
# Correct answer: acing
# Guesses made:  which, crime, acids, acini
# Number of guesses: 4
# ------------------------
# Correct answer: acini
# Guesses made:  which, crime, acids, acini
# Number of guesses: 4
# ------------------------
# Correct answer: ackee
# Guesses made:  which, could, scene
# Number of guesses: 3
# ------------------------
# Correct answer: acker
# Guesses made:  which, could, scene
# Number of guesses: 3
# ------------------------
# Correct answer: acmes
# Guesses made:  which, could, scene, acres
# Number of guesses: 4
# ------------------------
# Correct answer: acmic
# Guesses made:  which, music, comic, demic, gamic
# Number of guesses: 5
# ------------------------
# Correct answer: acned
# Guesses made:  which, could, faced, acted, acred
# Number of guesses: 5
# ------------------------
# Correct answer: acnes
# Guesses made:  which, could, scene
# Number of guesses: 3
# ------------------------
# Correct answer: acock
# Guesses made:  which, place, fancy, bocca, acock
# Number of guesses: 5
# ------------------------
# Correct answer: acold
# Guesses made:  which, could, scold
# Number of guesses: 3
# ------------------------
# Correct answer: acorn
# Guesses made:  which, could, scope
# Number of guesses: 3
# ------------------------
# Correct answer: acred
# Guesses made:  which, could, faced, acted, acred
# Number of guesses: 5
# ------------------------
# Correct answer: acres
# Guesses made:  which, could, scene, acres
# Number of guesses: 4
# ------------------------
# Correct answer: acrid
# Guesses made:  which, music, civil, tacit
# Number of guesses: 4
# ------------------------
# Correct answer: acros
# Guesses made:  which, could, scope, acros
# Number of guesses: 4
# ------------------------
# Correct answer: acted
# Guesses made:  which, could, faced, acted
# Number of guesses: 4
# ------------------------
# Correct answer: actin
# Guesses made:  which, music, civil, tacit
# Number of guesses: 4
# ------------------------
# Correct answer: acton
# Guesses made:  which, could, scope, actor
# Number of guesses: 4
# ------------------------
# Correct answer: actor
# Guesses made:  which, could, scope, actor
# Number of guesses: 4
# ------------------------
# Correct answer: acute
# Guesses made:  which, could, acute
# Number of guesses: 3
# ------------------------
# Correct answer: acyls
# Guesses made:  which, could, scale
# Number of guesses: 3
# ------------------------
# Correct answer: adage
# Guesses made:  which, about, asked, adage
# Number of guesses: 4
# ------------------------
# Correct answer: adapt
# Guesses made:  which, about, agent, apart
# Number of guesses: 4
# ------------------------
# Correct answer: adaws
# Guesses made:  which, power, awful
# Number of guesses: 3
# ------------------------
# Correct answer: adays
# Guesses made:  which, about, asked
# Number of guesses: 3
# ------------------------
# Correct answer: adbot
# Guesses made:  which, about
# Number of guesses: 2
# ------------------------
# Correct answer: addax
# Guesses made:  which, about, asked, adman
# Number of guesses: 4
# ------------------------
# Correct answer: added
# Guesses made:  which, about, asked, added
# Number of guesses: 4
# ------------------------
# Correct answer: adder
# Guesses made:  which, about, asked, alder
# Number of guesses: 4
# ------------------------
# Correct answer: addio
# Guesses made:  which, first, again, avoid, audio
# Number of guesses: 5
# ------------------------
# Correct answer: addle
# Guesses made:  which, about, asked, adage
# Number of guesses: 4
# ------------------------
# Correct answer: adeem
# Guesses made:  which, about, asked, alder, admen
# Number of guesses: 5
# ------------------------
# Correct answer: adept
# Guesses made:  which, about, agent, alert
# Number of guesses: 4
# ------------------------
# Correct answer: adhan
# Guesses made:  which, other, nahal
# Number of guesses: 3
# ------------------------
# Correct answer: adieu
# Guesses made:  which, being, quite
# Number of guesses: 3
# ------------------------
# Correct answer: adios
# Guesses made:  which, being, still, pairs, amiss
# Number of guesses: 5
# ------------------------
# Correct answer: adits
# Guesses made:  which, being, still, trips, omits, quits
# Number of guesses: 6
# ------------------------
# Correct answer: adman
# Guesses made:  which, about, asked, adman
# Number of guesses: 4
# ------------------------
# Correct answer: admen
# Guesses made:  which, about, asked, alder, admen
# Number of guesses: 5
# ------------------------
# Correct answer: admin
# Guesses made:  which, first, again, admin
# Number of guesses: 4
# ------------------------
# Correct answer: admit
# Guesses made:  which, first, input, admit
# Number of guesses: 4
# ------------------------
# Correct answer: admix
# Guesses made:  which, first, again, avoid
# Number of guesses: 4
# ------------------------
# Correct answer: adobe
# Guesses made:  which, about, adobe
# Number of guesses: 3
# ------------------------
# Correct answer: adobo
# Guesses made:  which, about, adobe
# Number of guesses: 3
# ------------------------
# Correct answer: adopt
# Guesses made:  which, about, adopt
# Number of guesses: 3
# ------------------------
# Correct answer: adore
# Guesses made:  which, about, among, arose, adore
# Number of guesses: 5
# ------------------------
# Correct answer: adorn
# Guesses made:  which, about, among, anode
# Number of guesses: 4
# ------------------------
# Correct answer: adown
# Guesses made:  which, power, known, blown, adown
# Number of guesses: 5
# ------------------------
# Correct answer: adoze
# Guesses made:  which, about, among, arose, azole
# Number of guesses: 5
# ------------------------
# Correct answer: adrad
# Guesses made:  which, about, asked, aland
# Number of guesses: 4
# ------------------------
# Correct answer: adred
# Guesses made:  which, about, asked, added, adzed
# Number of guesses: 5
# ------------------------
# Correct answer: adsum
# Guesses made:  which, about, argue, annul, adsum
# Number of guesses: 5
# ------------------------
# Correct answer: aduki
# Guesses made:  which, first, again, appui, azuki
# Number of guesses: 5
# ------------------------
# Correct answer: adult
# Guesses made:  which, about, adult
# Number of guesses: 3
# ------------------------
# Correct answer: adunc
# Guesses made:  which, could, scuds
# Number of guesses: 3
# ------------------------
# Correct answer: adust
# Guesses made:  which, about, adult
# Number of guesses: 3
# ------------------------
# Correct answer: advew
# Guesses made:  which, power, sweet, bedew
# Number of guesses: 4
# ------------------------
# Correct answer: adyta
# Guesses made:  which, about, after, atlas, anata
# Number of guesses: 5
# ------------------------
# Correct answer: adzed
# Guesses made:  which, about, asked, added, adzed
# Number of guesses: 5
# ------------------------
# Correct answer: adzes
# Guesses made:  which, about, asked, aedes
# Number of guesses: 4
# ------------------------
# Correct answer: aecia
# Guesses made:  which, music, civil, tacit
# Number of guesses: 4
# ------------------------
# Correct answer: aedes
# Guesses made:  which, about, asked, aedes
# Number of guesses: 4
# ------------------------
# Correct answer: aegis
# Guesses made:  which, first, issue, penis, lexis, aegis
# Number of guesses: 6
# ------------------------
# Correct answer: aeons
# Guesses made:  which, about, among, alone
# Number of guesses: 4
# ------------------------
# Correct answer: aerie
# Guesses made:  which, first, maria, aerie
# Number of guesses: 4
# ------------------------
# Correct answer: aeros
# Guesses made:  which, about, anglo, armor, aeros
# Number of guesses: 5
# ------------------------
# Correct answer: aesir
# Guesses made:  which, first, resin
# Number of guesses: 3
# ------------------------
# Correct answer: afald
# Guesses made:  which, about, asked, aland
# Number of guesses: 4
# ------------------------
# Correct answer: afara
# Guesses made:  which, about, asked, apply, amman
# Number of guesses: 5
# ------------------------
# Correct answer: afars
# Guesses made:  which, about, asked, arras, agars
# Number of guesses: 5
# ------------------------
# Correct answer: afear
# Guesses made:  which, about, asked, angle, arepa
# Number of guesses: 5
# ------------------------
# Correct answer: affix
# Guesses made:  which, first, mafia
# Number of guesses: 3
# ------------------------
# Correct answer: afire
# Guesses made:  which, being, quite, smile, drive, zaire
# Number of guesses: 6
# ------------------------
# Correct answer: aflaj
# Guesses made:  which, about, asked, apply, alarm, annal
# Number of guesses: 6
# ------------------------
# Correct answer: afoot
# Guesses made:  which, about, adopt, aloft
# Number of guesses: 4
# ------------------------
# Correct answer: afore
# Guesses made:  which, about, among, arose, adore
# Number of guesses: 5
# ------------------------
# Correct answer: afoul
# Guesses made:  which, about, aloud
# Number of guesses: 3
# ------------------------
# Correct answer: afrit
# Guesses made:  which, first
# Number of guesses: 2
# ------------------------
# Correct answer: afros
# Guesses made:  which, about, anglo, armor, aeros
# Number of guesses: 5
# ------------------------
# Correct answer: after
# Guesses made:  which, about, after
# Number of guesses: 3
# ------------------------
# Correct answer: again
# Guesses made:  which, first, again
# Number of guesses: 3
# ------------------------
# Correct answer: agama
# Guesses made:  which, about, asked, apply, amman
# Number of guesses: 5
# ------------------------
# Correct answer: agami
# Guesses made:  which, first, again
# Number of guesses: 3
# ------------------------
# Correct answer: agape
# Guesses made:  which, about, asked, angle, agape
# Number of guesses: 5
# ------------------------
# Correct answer: agars
# Guesses made:  which, about, asked, arras, agars
# Number of guesses: 5
# ------------------------
# Correct answer: agast
# Guesses made:  which, about, agent
# Number of guesses: 3
# ------------------------
# Correct answer: agate
# Guesses made:  which, about, after, agate
# Number of guesses: 4
# ------------------------
# Correct answer: agave
# Guesses made:  which, about, asked, angle, agape, agave
# Number of guesses: 6
# ------------------------
# Correct answer: agaze
# Guesses made:  which, about, asked, angle, agape, agave
# Number of guesses: 6
# ------------------------
# Correct answer: agene
# Guesses made:  which, about, asked, angle
# Number of guesses: 4
# ------------------------
# Correct answer: agent
# Guesses made:  which, about, agent
# Number of guesses: 3
# ------------------------
# Correct answer: agers
# Guesses made:  which, about, asked, areas, avers, agers
# Number of guesses: 6
# ------------------------
# Correct answer: agger
# Guesses made:  which, about, asked, anger
# Number of guesses: 4
# ------------------------
# Correct answer: aggie
# Guesses made:  which, first, again
# Number of guesses: 3
# ------------------------
# Correct answer: aggri
# Guesses made:  which, first, brain, mauri
# Number of guesses: 4
# ------------------------
# Correct answer: aggro
# Guesses made:  which, about, anglo
# Number of guesses: 3
# ------------------------
# Correct answer: aggry
# Guesses made:  which, about, asked, apply, angry
# Number of guesses: 5
# ------------------------
# Correct answer: aghas
# Guesses made:  which, other, nahal, aghas
# Number of guesses: 4
# ------------------------
# Correct answer: agila
# Guesses made:  which, being, guilt
# Number of guesses: 3
# ------------------------
# Correct answer: agile
# Guesses made:  which, being, guide, agile
# Number of guesses: 4
# ------------------------
# Correct answer: aging
# Guesses made:  which, being, going, using, lying, aging
# Number of guesses: 6
# ------------------------
# Correct answer: agios
# Guesses made:  which, being, guilt, amigo
# Number of guesses: 4
# ------------------------
# Correct answer: agism
# Guesses made:  which, being, guilt, amigo
# Number of guesses: 4
# ------------------------
# Correct answer: agist
# Guesses made:  which, being, guilt
# Number of guesses: 3
# ------------------------
# Correct answer: agita
# Guesses made:  which, being, guilt, taiga
# Number of guesses: 4
# ------------------------
# Correct answer: aglee
# Guesses made:  which, about, asked, anger, agley
# Number of guesses: 5
# ------------------------
# Correct answer: aglet
# Guesses made:  which, about, agent
# Number of guesses: 3
# ------------------------
# Correct answer: agley
# Guesses made:  which, about, asked, anger, agley
# Number of guesses: 5
# ------------------------
# Correct answer: agloo
# Guesses made:  which, about, anglo
# Number of guesses: 3
# ------------------------
# Correct answer: aglow
# Guesses made:  which, power, known, allow, aglow
# Number of guesses: 5
# ------------------------
# Correct answer: aglus
# Guesses made:  which, about, argue, almug
# Number of guesses: 4
# ------------------------
# Correct answer: agmas
# Guesses made:  which, about, asked, arras, annas, almas
# Number of guesses: 6
# ------------------------
# Correct answer: agoge
# Guesses made:  which, about, among, agora, agood
# Number of guesses: 5
# ------------------------
# Correct answer: agone
# Guesses made:  which, about, among, agony, agone
# Number of guesses: 5
# ------------------------
# Correct answer: agons
# Guesses made:  which, about, among, agony, agone
# Number of guesses: 5
# ------------------------
# Correct answer: agony
# Guesses made:  which, about, among, agony
# Number of guesses: 4
# ------------------------
# Correct answer: agood
# Guesses made:  which, about, among, agora, agood
# Number of guesses: 5
# ------------------------
# Correct answer: agora
# Guesses made:  which, about, among, agora
# Number of guesses: 4
# ------------------------
# Correct answer: agree
# Guesses made:  which, about, asked, anger
# Number of guesses: 4
# ------------------------
# Correct answer: agria
# Guesses made:  which, first, maria, noria
# Number of guesses: 4
# ------------------------
# Correct answer: agrin
# Guesses made:  which, first, maria, aerie, agrin
# Number of guesses: 5
# ------------------------
# Correct answer: agros
# Guesses made:  which, about, anglo
# Number of guesses: 3
# ------------------------
# Correct answer: agued
# Guesses made:  which, about, azure, agues
# Number of guesses: 4
# ------------------------
# Correct answer: agues
# Guesses made:  which, about, azure, agues
# Number of guesses: 4
# ------------------------
# Correct answer: aguna
# Guesses made:  which, about, azure, alums, ajuga
# Number of guesses: 5
# ------------------------
# Correct answer: aguti
# Guesses made:  which, first, until
# Number of guesses: 3
# ------------------------
# Correct answer: ahead
# Guesses made:  which, there, ahead
# Number of guesses: 3
# ------------------------
# Correct answer: aheap
# Guesses made:  which, there, ahead
# Number of guesses: 3
# ------------------------
# Correct answer: ahent
# Guesses made:  which, there, sheet
# Number of guesses: 3
# ------------------------
# Correct answer: ahigh
# Guesses made:  which, thigh
# Number of guesses: 2
# ------------------------
# Correct answer: ahind
# Guesses made:  which, think, shine, rhino, ahind
# Number of guesses: 5
# ------------------------
# Correct answer: ahing
# Guesses made:  which, think, shine, rhino, ahind
# Number of guesses: 5
# ------------------------
# Correct answer: ahint
# Guesses made:  which, think
# Number of guesses: 2
# ------------------------
# Correct answer: ahold
# Guesses made:  which, there, shall, ahold
# Number of guesses: 4
# ------------------------
# Correct answer: ahull
# Guesses made:  which, there, shall
# Number of guesses: 3
# ------------------------
# Correct answer: ahuru
# Guesses made:  which, there, sharp
# Number of guesses: 3
# ------------------------
# Correct answer: aidas
# Guesses made:  which, first, lives, signs, pious, disks, midis
# Number of guesses: 7
# ------------------------
# Correct answer: aided
# Guesses made:  which, first, given, liked, mixed, aided
# Number of guesses: 6
# ------------------------
# Correct answer: aider
# Guesses made:  which, first, river, piper, diner, eider, aider
# Number of guesses: 7
# ------------------------
# Correct answer: aides
# Guesses made:  which, first, lives, sides, aides
# Number of guesses: 5
# ------------------------
# Correct answer: aidoi
# Guesses made:  which, first, given, billy, pizza, miaou
# Number of guesses: 6
# ------------------------
# Correct answer: aidos
# Guesses made:  which, first, lives, signs, pious, aidos
# Number of guesses: 6
# ------------------------
# Correct answer: aiery
# Guesses made:  which, first, river, kiore
# Number of guesses: 4
# ------------------------
# Correct answer: aigas
# Guesses made:  which, first, lives, signs, biggs, gigas
# Number of guesses: 6
# ------------------------
# Correct answer: aight
# Guesses made:  which, right, might, night, light, eight, fight, sight, tight, bight, hight, aight
# Number of guesses: 12
# ------------------------
# Correct answer: ailed
# Guesses made:  which, first, given, liked, piled, oiled, ailed
# Number of guesses: 7
# ------------------------
# Correct answer: aimed
# Guesses made:  which, first, given, liked, mixed
# Number of guesses: 5
# ------------------------
# Correct answer: aimer
# Guesses made:  which, first, river, piper, diner, mixer
# Number of guesses: 6
# ------------------------
# Correct answer: ainee
# Guesses made:  which, first, given, lined, piney, zineb
# Number of guesses: 6
# ------------------------
# Correct answer: ainga
# Guesses made:  which, first, given, liang
# Number of guesses: 4
# ------------------------
# Correct answer: aioli
# Guesses made:  which, first, given, billy
# Number of guesses: 4
# ------------------------
# Correct answer: aired
# Guesses made:  which, first, viral, aired
# Number of guesses: 4
# ------------------------
# Correct answer: airer
# Guesses made:  which, first, viral, aired
# Number of guesses: 4
# ------------------------
# Correct answer: airns
# Guesses made:  which, first, girls, birds, virus, sires, kirks, miros, pirns
# Number of guesses: 9
# ------------------------
# Correct answer: airth
# Guesses made:  which, birth, mirth, girth, firth, airth
# Number of guesses: 6
# ------------------------
# Correct answer: airts
# Guesses made:  which, first, tires, girts, dirts
# Number of guesses: 5
# ------------------------
# Correct answer: aisle
# Guesses made:  which, first, lives, aisle
# Number of guesses: 4
# ------------------------
# Correct answer: aitch
# Guesses made:  which, pitch, ditch, mitch, hitch, fitch, titch, aitch
# Number of guesses: 8
# ------------------------
# Correct answer: aitus
# Guesses made:  which, first, times, lists, situs
# Number of guesses: 5
# ------------------------
# Correct answer: aiver
# Guesses made:  which, first, river, liver, giver, diver, viver, aiver
# Number of guesses: 8
# ------------------------
# Correct answer: aiyee
# Guesses made:  which, first, given, liked, mimeo
# Number of guesses: 5
# ------------------------
# Correct answer: aizle
# Guesses made:  which, first, given, bible, mille
# Number of guesses: 5
# ------------------------
# Correct answer: ajies
# Guesses made:  which, being, quite, dried, flies, skies, amies
# Number of guesses: 7
# ------------------------
# Correct answer: ajiva
# Guesses made:  which, being, still, prior, quiff, zaida
# Number of guesses: 6
# ------------------------
# Correct answer: ajuga
# Guesses made:  which, about, azure, alums, ajuga
# Number of guesses: 5
# ------------------------
# Correct answer: ajwan
# Guesses made:  which, power, lawns
# Number of guesses: 3
# ------------------------
# Correct answer: akees
# Guesses made:  which, about, asked
# Number of guesses: 3
# ------------------------
# Correct answer: akela
# Guesses made:  which, about, asked, akela
# Number of guesses: 4
# ------------------------
# Correct answer: akene
# Guesses made:  which, about, asked, akela
# Number of guesses: 4
# ------------------------
# Correct answer: aking
# Guesses made:  which, being, going, using, lying, aging, aking
# Number of guesses: 7
# ------------------------
# Correct answer: akita
# Guesses made:  which, being, still, drift, amity
# Number of guesses: 5
# ------------------------
# Correct answer: akkas
# Guesses made:  which, about, asked
# Number of guesses: 3
# ------------------------
# Correct answer: alaap
# Guesses made:  which, about, asked, apply, alaap
# Number of guesses: 5
# ------------------------
# Correct answer: alack
# Guesses made:  which, place, black, slack, clack, flack
# Number of guesses: 6
# ------------------------
# Correct answer: alamo
# Guesses made:  which, about, anglo
# Number of guesses: 3
# ------------------------
# Correct answer: aland
# Guesses made:  which, about, asked, aland
# Number of guesses: 4
# ------------------------
# Correct answer: alane
# Guesses made:  which, about, asked, angle
# Number of guesses: 4
# ------------------------
# Correct answer: alang
# Guesses made:  which, about, asked, apply, alarm
# Number of guesses: 5
# ------------------------
# Correct answer: alans
# Guesses made:  which, about, asked, arras, amass, alans
# Number of guesses: 6
# ------------------------
# Correct answer: alant
# Guesses made:  which, about, agent, avant
# Number of guesses: 4
# ------------------------
# Correct answer: alapa
# Guesses made:  which, about, asked, apply, alaap
# Number of guesses: 5
# ------------------------
# Correct answer: alaps
# Guesses made:  which, about, asked, arras, amass, alans, alays
# Number of guesses: 7
# ------------------------
# Correct answer: alarm
# Guesses made:  which, about, asked, apply, alarm
# Number of guesses: 5
# ------------------------
# Correct answer: alary
# Guesses made:  which, about, asked, apply, allay
# Number of guesses: 5
# ------------------------
# Correct answer: alate
# Guesses made:  which, about, after, agate, amate
# Number of guesses: 5
# ------------------------
# Correct answer: alays
# Guesses made:  which, about, asked, arras, amass, alans, alays
# Number of guesses: 7
# ------------------------
# Correct answer: albas
# Guesses made:  which, about, amber
# Number of guesses: 3
# ------------------------
# Correct answer: albee
# Guesses made:  which, about, amber
# Number of guesses: 3
# ------------------------
# Correct answer: album
# Guesses made:  which, about
# Number of guesses: 2
# ------------------------
# Correct answer: alcid
# Guesses made:  which, music, civil, alcid
# Number of guesses: 4
# ------------------------
# Correct answer: alcos
# Guesses made:  which, could, octal
# Number of guesses: 3
# ------------------------
# Correct answer: aldea
# Guesses made:  which, about, asked, alder
# Number of guesses: 4
# ------------------------
# Correct answer: alder
# Guesses made:  which, about, asked, alder
# Number of guesses: 4
# ------------------------
# Correct answer: aldol
# Guesses made:  which, about, anglo, alloy, aldol
# Number of guesses: 5
# ------------------------
# Correct answer: aleck
# Guesses made:  which, place, aleck
# Number of guesses: 3
# ------------------------
# Correct answer: alecs
# Guesses made:  which, place, aleck
# Number of guesses: 3
# ------------------------
# Correct answer: alefs
# Guesses made:  which, about, asked, areas, amens, axels
# Number of guesses: 6
# ------------------------
# Correct answer: aleft
# Guesses made:  which, about, agent, alert
# Number of guesses: 4
# ------------------------
# Correct answer: aleph
# Guesses made:  which, death, aleph
# Number of guesses: 3
# ------------------------
# Correct answer: alert
# Guesses made:  which, about, agent, alert
# Number of guesses: 4
# ------------------------
# Correct answer: alews
# Guesses made:  which, power, awake
# Number of guesses: 3
# ------------------------
# Correct answer: aleye
# Guesses made:  which, about, asked, angle
# Number of guesses: 4
# ------------------------
# Correct answer: alfas
# Guesses made:  which, about, asked, arras, annas, almas, alfas
# Number of guesses: 7
# ------------------------
# Correct answer: algae
# Guesses made:  which, about, asked, angle
# Number of guesses: 4
# ------------------------
# Correct answer: algal
# Guesses made:  which, about, asked, apply, alarm
# Number of guesses: 5
# ------------------------
# Correct answer: algas
# Guesses made:  which, about, asked, arras, annas, almas, alfas
# Number of guesses: 7
# ------------------------
# Correct answer: algid
# Guesses made:  which, first, again
# Number of guesses: 3
# ------------------------
# Correct answer: algin
# Guesses made:  which, first, again
# Number of guesses: 3
# ------------------------
# Correct answer: algor
# Guesses made:  which, about, anglo, algor
# Number of guesses: 4
# ------------------------
# Correct answer: algum
# Guesses made:  which, about, argue
# Number of guesses: 3
# ------------------------
# Correct answer: alias
# Guesses made:  which, being, still, alias
# Number of guesses: 4
# ------------------------
# Correct answer: alibi
# Guesses made:  which, being, alibi
# Number of guesses: 3
# ------------------------
# Correct answer: alien
# Guesses made:  which, being, noise
# Number of guesses: 3
# ------------------------
# Correct answer: alifs
# Guesses made:  which, being, still, alias
# Number of guesses: 4
# ------------------------
# Correct answer: align
# Guesses made:  which, being, align
# Number of guesses: 3
# ------------------------
# Correct answer: alike
# Guesses made:  which, being, quite, smile, alive
# Number of guesses: 5
# ------------------------
# Correct answer: aline
# Guesses made:  which, being, spine, urine, amine, aline
# Number of guesses: 6
# ------------------------
# Correct answer: alist
# Guesses made:  which, being, still, flits
# Number of guesses: 4
# ------------------------
# Correct answer: alive
# Guesses made:  which, being, quite, smile, alive
# Number of guesses: 5
# ------------------------
# Correct answer: aliya
# Guesses made:  which, being, still, laird
# Number of guesses: 4
# ------------------------
# Correct answer: alkie
# Guesses made:  which, first, again, avoid, alkie
# Number of guesses: 5
# ------------------------
# Correct answer: alkos
# Guesses made:  which, about, anglo, alloy, aldol
# Number of guesses: 5
# ------------------------
# Correct answer: alkyd
# Guesses made:  which, about, asked
# Number of guesses: 3
# ------------------------
# Correct answer: alkyl
# Guesses made:  which, about, asked
# Number of guesses: 3
# ------------------------
# Correct answer: allay
# Guesses made:  which, about, asked, apply, allay
# Number of guesses: 5
# ------------------------
# Correct answer: allee
# Guesses made:  which, about, asked, anger, alley, allee
# Number of guesses: 6
# ------------------------
# Correct answer: allel
# Guesses made:  which, about, asked, anger, alley, allee
# Number of guesses: 6
# ------------------------
# Correct answer: alley
# Guesses made:  which, about, asked, anger, alley
# Number of guesses: 5
# ------------------------
# Correct answer: allis
# Guesses made:  which, first, issue, solid, allis
# Number of guesses: 5
# ------------------------
# Correct answer: allod
# Guesses made:  which, about, anglo, alloy
# Number of guesses: 4
# ------------------------
# Correct answer: allot
# Guesses made:  which, about, allot
# Number of guesses: 3
# ------------------------
# Correct answer: allow
# Guesses made:  which, power, known, allow
# Number of guesses: 4
# ------------------------
# Correct answer: alloy
# Guesses made:  which, about, anglo, alloy
# Number of guesses: 4
# ------------------------
# Correct answer: allyl
# Guesses made:  which, about, asked, apply
# Number of guesses: 4
# ------------------------
# Correct answer: almah
# Guesses made:  which, death, laugh, almah
# Number of guesses: 4
# ------------------------
# Correct answer: almas
# Guesses made:  which, about, asked, arras, annas, almas
# Number of guesses: 6
# ------------------------
# Correct answer: almeh
# Guesses made:  which, death, aleph
# Number of guesses: 3
# ------------------------
# Correct answer: almes
# Guesses made:  which, about, asked, ayres, axles
# Number of guesses: 5
# ------------------------
# Correct answer: almud
# Guesses made:  which, about, argue, annul
# Number of guesses: 4
# ------------------------
# Correct answer: almug
# Guesses made:  which, about, argue, almug
# Number of guesses: 4
# ------------------------
# Correct answer: alods
# Guesses made:  which, about, among, arose, alods
# Number of guesses: 5
# ------------------------
# Correct answer: aloed
# Guesses made:  which, about, among, arose
# Number of guesses: 4
# ------------------------
# Correct answer: aloes
# Guesses made:  which, about, among, arose
# Number of guesses: 4
# ------------------------
# Correct answer: aloft
# Guesses made:  which, about, adopt, aloft
# Number of guesses: 4
# ------------------------
# Correct answer: aloha
# Guesses made:  which, other, holds
# Number of guesses: 3
# ------------------------
# Correct answer: aloin
# Guesses made:  which, first, again, admin, auxin
# Number of guesses: 5
# ------------------------
# Correct answer: alone
# Guesses made:  which, about, among, alone
# Number of guesses: 4
# ------------------------
# Correct answer: along
# Guesses made:  which, about, among
# Number of guesses: 3
# ------------------------
# Correct answer: aloof
# Guesses made:  which, about, among, arose, aloof
# Number of guesses: 5
# ------------------------
# Correct answer: aloos
# Guesses made:  which, about, among, arose, alods
# Number of guesses: 5
# ------------------------
# Correct answer: aloud
# Guesses made:  which, about, aloud
# Number of guesses: 3
# ------------------------
# Correct answer: alowe
# Guesses made:  which, power, below, swole
# Number of guesses: 4
# ------------------------
# Correct answer: alpha
# Guesses made:  which, other, human, alpha
# Number of guesses: 4
# ------------------------
# Correct answer: altar
# Guesses made:  which, about, after, altar
# Number of guesses: 4
# ------------------------
# Correct answer: alter
# Guesses made:  which, about, after, alter
# Number of guesses: 4
# ------------------------
# Correct answer: altho
# Guesses made:  which, other, hosts
# Number of guesses: 3
# ------------------------
# Correct answer: altos
# Guesses made:  which, about, aorta, atmos
# Number of guesses: 4
# ------------------------
# Correct answer: alula
# Guesses made:  which, about, azure, alums
# Number of guesses: 4
# ------------------------
# Correct answer: alums
# Guesses made:  which, about, azure, alums
# Number of guesses: 4
# ------------------------
# Correct answer: alure
# Guesses made:  which, about, azure
# Number of guesses: 3
# ------------------------
# Correct answer: alvar
# Guesses made:  which, about, asked, apply, alarm
# Number of guesses: 5
# ------------------------
# Correct answer: alway
# Guesses made:  which, power, lawns
# Number of guesses: 3
# ------------------------
# Correct answer: amahs
# Guesses made:  which, other, human, amahs
# Number of guesses: 4
# ------------------------
# Correct answer: amain
# Guesses made:  which, first, again
# Number of guesses: 3
# ------------------------
# Correct answer: amass
# Guesses made:  which, about, asked, arras, amass
# Number of guesses: 5
# ------------------------
# Correct answer: amate
# Guesses made:  which, about, after, agate, amate
# Number of guesses: 5
# ------------------------
# Correct answer: amaut
# Guesses made:  which, about, amaut
# Number of guesses: 3
# ------------------------
# Correct answer: amaze
# Guesses made:  which, about, asked, angle, amaze
# Number of guesses: 5
# ------------------------
# Correct answer: amban
# Guesses made:  which, about, amber
# Number of guesses: 3
# ------------------------
# Correct answer: amber
# Guesses made:  which, about, amber
# Number of guesses: 3
# ------------------------
# Correct answer: ambit
# Guesses made:  which, first, input, admit
# Number of guesses: 4
# ------------------------
# Correct answer: amble
# Guesses made:  which, about, amber
# Number of guesses: 3
# ------------------------
# Correct answer: ambos
# Guesses made:  which, about, arbor
# Number of guesses: 3
# ------------------------
# Correct answer: ambry
# Guesses made:  which, about, amber
# Number of guesses: 3
# ------------------------
# Correct answer: ameba
# Guesses made:  which, about, amber
# Number of guesses: 3
# ------------------------
# Correct answer: ameer
# Guesses made:  which, about, asked, anger, ameer
# Number of guesses: 5
# ------------------------
# Correct answer: amend
# Guesses made:  which, about, asked, amend
# Number of guesses: 4
# ------------------------
# Correct answer: amene
# Guesses made:  which, about, asked, angle, arene
# Number of guesses: 5
# ------------------------
# Correct answer: amens
# Guesses made:  which, about, asked, areas, amens
# Number of guesses: 5
# ------------------------
# Correct answer: ament
# Guesses made:  which, about, agent, anent
# Number of guesses: 4
# ------------------------
# Correct answer: amias
# Guesses made:  which, being, still, pairs, amiss, amias
# Number of guesses: 6
# ------------------------
# Correct answer: amice
# Guesses made:  which, voice, price, juice, slice, amice
# Number of guesses: 6
# ------------------------
# Correct answer: amici
# Guesses made:  which, voice, quick, spicy
# Number of guesses: 4
# ------------------------
# Correct answer: amide
# Guesses made:  which, being, quite, smile, amide
# Number of guesses: 5
# ------------------------
# Correct answer: amido
# Guesses made:  which, being, still, prior, ouija, amido
# Number of guesses: 6
# ------------------------
# Correct answer: amids
# Guesses made:  which, being, still, pairs, amiss, amias
# Number of guesses: 6
# ------------------------
# Correct answer: amies
# Guesses made:  which, being, quite, dried, flies, skies, amies
# Number of guesses: 7
# ------------------------
# Correct answer: amiga
# Guesses made:  which, being, guilt, amigo
# Number of guesses: 4
# ------------------------
# Correct answer: amigo
# Guesses made:  which, being, guilt, amigo
# Number of guesses: 4
# ------------------------
# Correct answer: amine
# Guesses made:  which, being, spine, urine, amine
# Number of guesses: 5
# ------------------------
# Correct answer: amino
# Guesses made:  which, being, point, amino
# Number of guesses: 4
# ------------------------
# Correct answer: amins
# Guesses made:  which, being, point, drink, mains
# Number of guesses: 5
# ------------------------
# Correct answer: amirs
# Guesses made:  which, being, still, pairs
# Number of guesses: 4
# ------------------------
# Correct answer: amiss
# Guesses made:  which, being, still, pairs, amiss
# Number of guesses: 5
# ------------------------
# Correct answer: amity
# Guesses made:  which, being, still, drift, amity
# Number of guesses: 5
# ------------------------
# Correct answer: amlas
# Guesses made:  which, about, asked, arras, annas, almas
# Number of guesses: 6
# ------------------------
# Correct answer: amman
# Guesses made:  which, about, asked, apply, amman
# Number of guesses: 5
# ------------------------
# Correct answer: ammon
# Guesses made:  which, about, anglo, apron
# Number of guesses: 4
# ------------------------
# Correct answer: ammos
# Guesses made:  which, about, anglo, armor
# Number of guesses: 4
# ------------------------
# Correct answer: amnia
# Guesses made:  which, first, again, anvil, amnio
# Number of guesses: 5
# ------------------------
# Correct answer: amnic
# Guesses made:  which, music, comic
# Number of guesses: 3
# ------------------------
# Correct answer: amnio
# Guesses made:  which, first, again, anvil, amnio
# Number of guesses: 5
# ------------------------
# Correct answer: amoks
# Guesses made:  which, about, among, amole
# Number of guesses: 4
# ------------------------
# Correct answer: amole
# Guesses made:  which, about, among, amole
# Number of guesses: 4
# ------------------------
# Correct answer: among
# Guesses made:  which, about, among
# Number of guesses: 3
# ------------------------
# Correct answer: amort
# Guesses made:  which, about, adopt, aloft, ayont
# Number of guesses: 5
# ------------------------
# Correct answer: amour
# Guesses made:  which, about, aloud
# Number of guesses: 3
# ------------------------
# Correct answer: amove
# Guesses made:  which, about, among, amole
# Number of guesses: 4
# ------------------------
# Correct answer: amowt
# Guesses made:  which, power, known, flows
# Number of guesses: 4
# ------------------------
# Correct answer: amped
# Guesses made:  which, about, asked, added, armed
# Number of guesses: 5
# ------------------------
# Correct answer: ample
# Guesses made:  which, about, asked, angle, apple
# Number of guesses: 5
# ------------------------
# Correct answer: amply
# Guesses made:  which, about, asked, apply
# Number of guesses: 4
# ------------------------
# Correct answer: ampul
# Guesses made:  which, about, argue, annul
# Number of guesses: 4
# ------------------------
# Correct answer: amrit
# Guesses made:  which, first, merit
# Number of guesses: 3
# ------------------------
# Correct answer: amuck
# Guesses made:  which, place, fancy, bocca
# Number of guesses: 4
# ------------------------
# Correct answer: amuse
# Guesses made:  which, about, azure, amuse
# Number of guesses: 4
# ------------------------
# Correct answer: amyls
# Guesses made:  which, about, asked, arras, amass
# Number of guesses: 5
# ------------------------
# Correct answer: anana
# Guesses made:  which, about, asked, apply, amman
# Number of guesses: 5
# ------------------------
# Correct answer: anata
# Guesses made:  which, about, after, atlas, anata
# Number of guesses: 5
# ------------------------
# Correct answer: ancho
# Guesses made:  which, cohen, nacho
# Number of guesses: 3
# ------------------------
# Correct answer: ancle
# Guesses made:  which, could, scale, ancle
# Number of guesses: 4
# ------------------------
# Correct answer: ancon
# Guesses made:  which, could, scope, bacon
# Number of guesses: 4
# ------------------------
# Correct answer: andro
# Guesses made:  which, about, anglo
# Number of guesses: 3
# ------------------------
# Correct answer: anear
# Guesses made:  which, about, asked, angle
# Number of guesses: 4
# ------------------------
# Correct answer: anele
# Guesses made:  which, about, asked, angle
# Number of guesses: 4
# ------------------------
# Correct answer: anent
# Guesses made:  which, about, agent, anent
# Number of guesses: 4
# ------------------------
# Correct answer: angas
# Guesses made:  which, about, asked, arras, annas, angas
# Number of guesses: 6
# ------------------------
# Correct answer: angel
# Guesses made:  which, about, asked, anger
# Number of guesses: 4
# ------------------------
# Correct answer: anger
# Guesses made:  which, about, asked, anger
# Number of guesses: 4
# ------------------------
# Correct answer: angle
# Guesses made:  which, about, asked, angle
# Number of guesses: 4
# ------------------------
# Correct answer: anglo
# Guesses made:  which, about, anglo
# Number of guesses: 3
# ------------------------
# Correct answer: angry
# Guesses made:  which, about, asked, apply, angry
# Number of guesses: 5
# ------------------------
# Correct answer: angst
# Guesses made:  which, about, agent
# Number of guesses: 3
# ------------------------
# Correct answer: anigh
# Guesses made:  which, faith, anigh
# Number of guesses: 3
# ------------------------
# Correct answer: anile
# Guesses made:  which, being, noise, knife, unite, anime
# Number of guesses: 6
# ------------------------
# Correct answer: anils
# Guesses made:  which, being, union, sniff, knits
# Number of guesses: 5
# ------------------------
# Correct answer: anima
# Guesses made:  which, being, union, sniff, anima
# Number of guesses: 5
# ------------------------
# Correct answer: anime
# Guesses made:  which, being, noise, knife, unite, anime
# Number of guesses: 6
# ------------------------
# Correct answer: animi
# Guesses made:  which, being, union, sniff, anima
# Number of guesses: 5
# ------------------------
# Correct answer: anion
# Guesses made:  which, being, union, onion, anion
# Number of guesses: 5
# ------------------------
# Correct answer: anise
# Guesses made:  which, being, noise
# Number of guesses: 3
# ------------------------
# Correct answer: anker
# Guesses made:  which, about, asked
# Number of guesses: 3
# ------------------------
# Correct answer: ankhs
# Guesses made:  which, other, human
# Number of guesses: 3
# ------------------------
# Correct answer: ankle
# Guesses made:  which, about, asked
# Number of guesses: 3
# ------------------------
# Correct answer: ankus
# Guesses made:  which, about, argue, annul
# Number of guesses: 4
# ------------------------
# Correct answer: anlas
# Guesses made:  which, about, asked, arras, annas, angas
# Number of guesses: 6
# ------------------------
# Correct answer: annal
# Guesses made:  which, about, asked, apply, alarm, annal
# Number of guesses: 6
# ------------------------
# Correct answer: annas
# Guesses made:  which, about, asked, arras, annas
# Number of guesses: 5
# ------------------------
# Correct answer: annat
# Guesses made:  which, about, agent
# Number of guesses: 3
# ------------------------
# Correct answer: annex
# Guesses made:  which, about, asked, anger
# Number of guesses: 4
# ------------------------
# Correct answer: annoy
# Guesses made:  which, about, anglo, annoy
# Number of guesses: 4
# ------------------------
# Correct answer: annul
# Guesses made:  which, about, argue, annul
# Number of guesses: 4
# ------------------------
# Correct answer: anoas
# Guesses made:  which, about, among, anode
# Number of guesses: 4
# ------------------------
# Correct answer: anode
# Guesses made:  which, about, among, anode
# Number of guesses: 4
# ------------------------
# Correct answer: anole
# Guesses made:  which, about, among, anode
# Number of guesses: 4
# ------------------------
# ...
# Number of guesses: 4
# ------------------------
# Correct answer: leash
# Guesses made:  which, death
# Number of guesses: 2
# ------------------------
# Correct answer: least
# Guesses made:  which, about, great, least
# Number of guesses: 4
# ------------------------
# Correct answer: leats
# Guesses made:  which, about, state, meats, feats, teats, peats, geats, neats, leats
# Number of guesses: 10
# ------------------------
# Correct answer: leave
# Guesses made:  which, about, years, leave
# Number of guesses: 4
# ------------------------
# Correct answer: leavy
# Guesses made:  which, about, years, leafy, leaky, leavy
# Number of guesses: 6
# ------------------------
# Correct answer: leaze
# Guesses made:  which, about, years, leave
# Number of guesses: 4
# ------------------------
# Correct answer: leben
# Guesses made:  which, about, belly, rebel
# Number of guesses: 4
# ------------------------
# Correct answer: leccy
# Guesses made:  which, place, telco
# Number of guesses: 3
# ------------------------
# Correct answer: ledes
# Guesses made:  which, about, never, sexes, memes, leges, ledes
# Number of guesses: 7
# ------------------------
# Correct answer: ledge
# Guesses made:  which, about, never, seems, kelly, ledge
# Number of guesses: 6
# ------------------------
# Correct answer: ledgy
# Guesses made:  which, about, never, seems, kelly, leggy
# Number of guesses: 6
# ------------------------
# Correct answer: ledum
# Guesses made:  which, about, jesus, venue, femur, ledum
# Number of guesses: 6
# ------------------------
# Correct answer: leear
# Guesses made:  which, about, years, renal, velar
# Number of guesses: 5
# ------------------------
# Correct answer: leech
# Guesses made:  which, march, touch, bench, leech
# Number of guesses: 5
# ------------------------
# Correct answer: leeks
# Guesses made:  which, about, never, seems, feels, leeks
# Number of guesses: 6
# ------------------------
# Correct answer: leeps
# Guesses made:  which, about, never, seems, feels, leeks
# Number of guesses: 6
# ------------------------
# Correct answer: leers
# Guesses made:  which, about, never, reply
# Number of guesses: 4
# ------------------------
# Correct answer: leery
# Guesses made:  which, about, never, reply
# Number of guesses: 4
# ------------------------
# Correct answer: leese
# Guesses made:  which, about, never, seems, geese, leese
# Number of guesses: 6
# ------------------------
# Correct answer: leets
# Guesses made:  which, about, terms, nests, pelts, lefts
# Number of guesses: 6
# ------------------------
# Correct answer: leeze
# Guesses made:  which, about, never, seems, geeky, jeeze, leeze
# Number of guesses: 7
# ------------------------
# Correct answer: lefte
# Guesses made:  which, about, terms, petty, kente
# Number of guesses: 5
# ------------------------
# Correct answer: lefts
# Guesses made:  which, about, terms, nests, pelts, lefts
# Number of guesses: 6
# ------------------------
# Correct answer: lefty
# Guesses made:  which, about, terms, petty, lefty
# Number of guesses: 5
# ------------------------
# Correct answer: legal
# Guesses made:  which, about, years, legal
# Number of guesses: 4
# ------------------------
# Correct answer: leger
# Guesses made:  which, about, never, refer, leper
# Number of guesses: 5
# ------------------------
# Correct answer: leges
# Guesses made:  which, about, never, sexes, memes, leges
# Number of guesses: 6
# ------------------------
# Correct answer: legge
# Guesses made:  which, about, never, seems, kelly, ledge
# Number of guesses: 6
# ------------------------
# Correct answer: leggo
# Guesses made:  which, about, order, enjoy, solve, leggo
# Number of guesses: 6
# ------------------------
# Correct answer: leggy
# Guesses made:  which, about, never, seems, kelly, leggy
# Number of guesses: 6
# ------------------------
# Correct answer: legit
# Guesses made:  which, first, input, admit, legit
# Number of guesses: 5
# ------------------------
# Correct answer: lehrs
# Guesses made:  which, other, rehab
# Number of guesses: 3
# ------------------------
# Correct answer: lehua
# Guesses made:  which, other, jehad, lehua
# Number of guesses: 4
# ------------------------
# Correct answer: leirs
# Guesses made:  which, being, seize, veils
# Number of guesses: 4
# ------------------------
# Correct answer: leish
# Guesses made:  which, faith, neigh
# Number of guesses: 3
# ------------------------
# Correct answer: leman
# Guesses made:  which, about, years, legal
# Number of guesses: 4
# ------------------------
# Correct answer: lemed
# Guesses made:  which, about, never, sexes, keyed, deled
# Number of guesses: 6
# ------------------------
# Correct answer: lemel
# Guesses made:  which, about, never, sexes, keyed, melee, lemel
# Number of guesses: 7
# ------------------------
# Correct answer: lemes
# Guesses made:  which, about, never, sexes, memes, demes, lemes
# Number of guesses: 7
# ------------------------
# Correct answer: lemma
# Guesses made:  which, about, years, legal, lemma
# Number of guesses: 5
# ------------------------
# Correct answer: lemme
# Guesses made:  which, about, never, seems, femme
# Number of guesses: 5
# ------------------------
# Correct answer: lemon
# Guesses made:  which, about, order, enjoy, lemon
# Number of guesses: 5
# ------------------------
# Correct answer: lemur
# Guesses made:  which, about, jesus, venue, femur, demur
# Number of guesses: 6
# ------------------------
# Correct answer: lends
# Guesses made:  which, about, never, sense, lends
# Number of guesses: 5
# ------------------------
# Correct answer: lenes
# Guesses made:  which, about, never, genes, denes, menes, penes, senes
# Number of guesses: 8
# ------------------------
# Correct answer: lengs
# Guesses made:  which, about, never, sense, lends
# Number of guesses: 5
# ------------------------
# Correct answer: lenis
# Guesses made:  which, first, issue, penis, denis, lenis
# Number of guesses: 6
# ------------------------
# Correct answer: lenos
# Guesses made:  which, about, order, enjoy, lemon
# Number of guesses: 5
# ------------------------
# Correct answer: lense
# Guesses made:  which, about, never, sense, dense, mense
# Number of guesses: 6
# ------------------------
# Correct answer: lenti
# Guesses made:  which, first, until
# Number of guesses: 3
# ------------------------
# Correct answer: lento
# Guesses made:  which, about, often, monte
# Number of guesses: 4
# ------------------------
# Correct answer: leone
# Guesses made:  which, about, floor, looks
# Number of guesses: 4
# ------------------------
# Correct answer: leper
# Guesses made:  which, about, never, refer, leper
# Number of guesses: 5
# ------------------------
# Correct answer: lepid
# Guesses made:  which, first, again, movie, equip
# Number of guesses: 5
# ------------------------
# Correct answer: lepra
# Guesses made:  which, about, years, verra
# Number of guesses: 4
# ------------------------
# Correct answer: lepta
# Guesses made:  which, about, state, delta
# Number of guesses: 4
# ------------------------
# Correct answer: lered
# Guesses made:  which, about, never, repel, leres
# Number of guesses: 5
# ------------------------
# Correct answer: leres
# Guesses made:  which, about, never, repel, leres
# Number of guesses: 5
# ------------------------
# Correct answer: lerps
# Guesses made:  which, about, never, reply
# Number of guesses: 4
# ------------------------
# Correct answer: leses
# Guesses made:  which, about, never, sexes, memes, leges, ledes, leses
# Number of guesses: 8
# ------------------------
# Correct answer: lests
# Guesses made:  which, about, terms, nests, pests, vests, jests, gests, fests, zests, lests
# Number of guesses: 11
# ------------------------
# Correct answer: letch
# Guesses made:  which, march, touch, fetch, ketch, vetch
# Number of guesses: 6
# ------------------------
# Correct answer: lethe
# Guesses made:  which, other, haste, lethe
# Number of guesses: 4
# ------------------------
# Correct answer: letup
# Guesses made:  which, about, setup, getup
# Number of guesses: 4
# ------------------------
# Correct answer: leuch
# Guesses made:  which, march, touch, heuch
# Number of guesses: 4
# ------------------------
# Correct answer: leuco
# Guesses made:  which, place, telco
# Number of guesses: 3
# ------------------------
# Correct answer: leuds
# Guesses made:  which, about, under, elude
# Number of guesses: 4
# ------------------------
# Correct answer: leugh
# Guesses made:  which, death, heugh
# Number of guesses: 3
# ------------------------
# Correct answer: levas
# Guesses made:  which, about, years, vegas, devas
# Number of guesses: 5
# ------------------------
# Correct answer: levee
# Guesses made:  which, about, never, level, levee
# Number of guesses: 5
# ------------------------
# Correct answer: level
# Guesses made:  which, about, never, level
# Number of guesses: 4
# ------------------------
# Correct answer: lever
# Guesses made:  which, about, never, fever, lever
# Number of guesses: 5
# ------------------------
# Correct answer: leves
# Guesses made:  which, about, never, level, levee
# Number of guesses: 5
# ------------------------
# Correct answer: levin
# Guesses made:  which, first, again, levin
# Number of guesses: 4
# ------------------------
# Correct answer: levis
# Guesses made:  which, first, issue, penis, lexis
# Number of guesses: 5
# ------------------------
# Correct answer: lewis
# Guesses made:  which, views
# Number of guesses: 2
# ------------------------
# Correct answer: lexes
# Guesses made:  which, about, never, sexes, lexes
# Number of guesses: 5
# ------------------------
# Correct answer: lexis
# Guesses made:  which, first, issue, penis, lexis
# Number of guesses: 5
# ------------------------
# Correct answer: lezes
# Guesses made:  which, about, never, sexes, memes, leges, ledes, leses
# Number of guesses: 8
# ------------------------
# Correct answer: lezza
# Guesses made:  which, about, years, legal, lemma
# Number of guesses: 5
# ------------------------
# Correct answer: lezzy
# Guesses made:  which, about, never, seems, kelly, leggy
# Number of guesses: 6
# ------------------------
# Correct answer: liana
# Guesses made:  which, first, given, piano
# Number of guesses: 4
# ------------------------
# Correct answer: liane
# Guesses made:  which, first, given, diane
# Number of guesses: 4
# ------------------------
# Correct answer: liang
# Guesses made:  which, first, given, liang
# Number of guesses: 4
# ------------------------
# Correct answer: liard
# Guesses made:  which, first, river, diary
# Number of guesses: 4
# ------------------------
# Correct answer: liars
# Guesses made:  which, first, risks, piers
# Number of guesses: 4
# ------------------------
# Correct answer: liart
# Guesses made:  which, first, rivet
# Number of guesses: 3
# ------------------------
# Correct answer: libel
# Guesses made:  which, first, given, liked, libel
# Number of guesses: 5
# ------------------------
# Correct answer: liber
# Guesses made:  which, first, river, piper, diner, mixer, liber
# Number of guesses: 7
# ------------------------
# Correct answer: libra
# Guesses made:  which, first, river, diary, libra
# Number of guesses: 5
# ------------------------
# Correct answer: libri
# Guesses made:  which, first, river, diary
# Number of guesses: 4
# ------------------------
# Correct answer: lichi
# Guesses made:  which, nicht, vichy, fiche
# Number of guesses: 4
# ------------------------
# Correct answer: licht
# Guesses made:  which, nicht, licht
# Number of guesses: 3
# ------------------------
# Correct answer: licit
# Guesses made:  which, music, civil
# Number of guesses: 3
# ------------------------
# Correct answer: licks
# Guesses made:  which, music, picks, kicks, ticks, licks
# Number of guesses: 6
# ------------------------
# Correct answer: lidar
# Guesses made:  which, first, river, minor, pilar
# Number of guesses: 5
# ------------------------
# Correct answer: lidos
# Guesses made:  which, first, lives, links, limbs, lisps, lidos
# Number of guesses: 7
# ------------------------
# Correct answer: liefs
# Guesses made:  which, first, lifes
# Number of guesses: 3
# ------------------------
# Correct answer: liege
# Guesses made:  which, first, given, liege
# Number of guesses: 4
# ------------------------
# Correct answer: liens
# Guesses made:  which, first, lives, liens
# Number of guesses: 4
# ------------------------
# Correct answer: liers
# Guesses made:  which, first, risks, piers, biers, liers
# Number of guesses: 6
# ------------------------
# Correct answer: lieus
# Guesses made:  which, first, lives, liens
# Number of guesses: 4
# ------------------------
# Correct answer: lieve
# Guesses made:  which, first, given, vilde
# Number of guesses: 4
# ------------------------
# Correct answer: lifer
# Guesses made:  which, first, rifle
# Number of guesses: 3
# ------------------------
# Correct answer: lifes
# Guesses made:  which, first, lifes
# Number of guesses: 3
# ------------------------
# Correct answer: lifts
# Guesses made:  which, first, gifts, lifts
# Number of guesses: 4
# ------------------------
# Correct answer: ligan
# Guesses made:  which, first, given, ligan
# Number of guesses: 4
# ------------------------
# Correct answer: liger
# Guesses made:  which, first, river, piper, diner, mixer, liber, liker
# Number of guesses: 8
# ------------------------
# Correct answer: ligge
# Guesses made:  which, first, given, liege
# Number of guesses: 4
# ------------------------
# Correct answer: light
# Guesses made:  which, right, might, night, light
# Number of guesses: 5
# ------------------------
# Correct answer: ligne
# Guesses made:  which, first, given, binge, ligne
# Number of guesses: 5
# ------------------------
# Correct answer: liked
# Guesses made:  which, first, given, liked
# Number of guesses: 4
# ------------------------
# Correct answer: liken
# Guesses made:  which, first, given, linen, liken
# Number of guesses: 5
# ------------------------
# Correct answer: liker
# Guesses made:  which, first, river, piper, diner, mixer, liber, liker
# Number of guesses: 8
# ------------------------
# Correct answer: likes
# Guesses made:  which, first, lives, lines, likes
# Number of guesses: 5
# ------------------------
# Correct answer: likin
# Guesses made:  which, first, given, liman, likin
# Number of guesses: 5
# ------------------------
# Correct answer: lilac
# Guesses made:  which, music, lilac
# Number of guesses: 3
# ------------------------
# Correct answer: lills
# Guesses made:  which, first, lives, links, limbs, lisps, lidos
# Number of guesses: 7
# ------------------------
# Correct answer: lilos
# Guesses made:  which, first, lives, links, limbs, lisps, lidos
# Number of guesses: 7
# ------------------------
# Correct answer: lilts
# Guesses made:  which, first, times, lists, lints
# Number of guesses: 5
# ------------------------
# Correct answer: liman
# Guesses made:  which, first, given, liman
# Number of guesses: 4
# ------------------------
# Correct answer: limas
# Guesses made:  which, first, lives, links, limbs, limps, limos
# Number of guesses: 7
# ------------------------
# Correct answer: limax
# Guesses made:  which, first, given, billy, lipid, limma
# Number of guesses: 6
# ------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 4
#       2 for word in words:
#       3     solver.reset()  # reset solver's possible words
# ----> 4     guesses = test_solver(solver, word)
#       5     results[word] = len(guesses)
#       6     print(f"Correct answer: {word}")
#
# Cell In[3], line 5, in test_solver(solver, word)
#       3 guesses = []
#       4 while len(solver.possible_words) > 1:
# ----> 5     guess = solver.get_optimal_guess()
#       6     guesses.append(guess)
#       7     solver.adjust_guess(guess, feedback(word, guess))
#
# File C:\Code\GitHub\Wordle\wordle_solver.py:50, in WordleSolver.get_optimal_guess(self)
#      48 def get_optimal_guess(self):
#      49     if self.possible_words:
# ---> 50         optimal_word = max(self.possible_words, key=self.get_word_score)
#      51         return optimal_word
#      52     else:
#
# File C:\Code\GitHub\Wordle\wordle_solver.py:58, in WordleSolver.get_word_score(self, word)
#      56 def get_word_score(self, word):
#      57     word_score = self.word_freq.get(word, 0)
# ---> 58     letter_score = sum(self.letter_freq.get(letter, 0) for letter in word)
#      59     return word_score + letter_score
#
# File C:\Code\GitHub\Wordle\wordle_solver.py:58, in <genexpr>(.0)
#      56 def get_word_score(self, word):
#      57     word_score = self.word_freq.get(word, 0)
# ---> 58     letter_score = sum(self.letter_freq.get(letter, 0) for letter in word)
#      59     return word_score + letter_score
#
# KeyboardInterrupt:

# %%
with open('results.json', 'w') as fp:
    json.dump(results, fp)
